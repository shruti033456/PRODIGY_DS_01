# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('flight_delays.csv',  encoding='utf-8')
df.head()
flight_delay_data = pd.read_csv('flight_delays.csv', index_col="Month")

# %%
plt.figure(figsize=(10,6))

# %%
plt.title("Flight delays")
# Out:
# Text(0.5, 1.0, 'Flight delays')

# %%
sns.barplot(x=flight_delay_data.index, y= flight_delay_data['NK'])
# Out:
# <Axes: xlabel='Month', ylabel='NK'>
